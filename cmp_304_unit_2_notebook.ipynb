# %%
# importing libraries
import pandas as pd

# initialising variables
tsvFile = 'dnd_chars_all.tsv'
csvTable = pd.read_table(tsvFile, sep = '\t')

# Convert file to csv file
csvTable.to_csv('dnd_chars_all.csv', index = False)

# Output to show that it worked
print('Table converted Successfully!')
csvTable.head()
# Out:
# Table converted Successfully!
#         ip   finger                              hash      name  \
# 0      NaN  ed15f9d  fe3ed6570067d2cd808bcee0a4396824  ee1e382c
# 1      NaN  ed15f9d  aa656cef94740b1da714d82782d8a8c4  ee1e382c
# 2  6b5d3f4  d922658  04b9abba9ce759ef13319c520bf0eb69  f1f6ff43
# 3  9b7218f  b5d19a0  ba92372c716a832e03e866447cb2d102  f92bdd74
# 4  9b7218f  b5d19a0  2f4a637dd42b9aa945abf870fe34edcf  f92bdd74
#
#              race              background                  date  \
# 0      Hill Dwarf  Guild Member - Justice  2022-08-23T20:02:11Z
# 1      Hill Dwarf  Guild Member - Justice  2022-08-23T19:43:25Z
# 2           Human                   Noble  2022-08-22T14:57:09Z
# 3  Fallen Aasimar               Outlander  2022-08-22T12:12:53Z
# 4  Fallen Aasimar               Outlander  2022-08-22T12:07:21Z
#
#                   class        justClass                         subclass  \
# 0  Sorcerer 13|Cleric 1  Sorcerer|Cleric      Clockwork Soul|Order Domain
# 1  Sorcerer 13|Cleric 1  Sorcerer|Cleric      Clockwork Soul|Order Domain
# 2            Fighter 13          Fighter                  Eldritch Knight
# 3    Sorcerer 3|Druid 2   Sorcerer|Druid  Shadow Magic|Circle of Wildfire
# 4    Sorcerer 3|Druid 2   Sorcerer|Druid  Shadow Magic|Circle of Wildfire
#
#    ...                                            choices        country  \
# 0  ...  metamagic/Twinned Spell*Subtle Spell*Quickened...         Canada
# 1  ...  metamagic/Twinned Spell*Subtle Spell*Quickened...         Canada
# 2  ...                             fighting style/Defense  United States
# 3  ...           metamagic/Transmuted Spell*Seeking Spell         Brazil
# 4  ...           metamagic/Transmuted Spell*Seeking Spell         Brazil
#
#    countryCode  processedAlignment  good  lawful  processedRace  \
# 0           CA                 NaN   NaN     NaN          Dwarf
# 1           CA                 NaN   NaN     NaN          Dwarf
# 2           US                  CG   NaN     NaN          Human
# 3           BR                 NaN   NaN     NaN        Aasimar
# 4           BR                 NaN   NaN     NaN        Aasimar
#
#                                      processedSpells  \
# 0  Alarm*1|Protection from Evil and Good*1|Comman...
# 1  Alarm*1|Protection from Evil and Good*1|Comman...
# 2  Prestidigitation*0|Mage Hand*0|Blade Ward*0|Li...
# 3           Burning Hands*1|Cure Wounds*1|Darkness*2
# 4           Burning Hands*1|Cure Wounds*1|Darkness*2
#
#                         processedWeapons                alias
# 0                 Crossbow, Light|Dagger      thirsty_davinci
# 1                 Crossbow, Light|Dagger      thirsty_davinci
# 2  Longsword|Dagger|Crossbow, Light|Mace          cool_bhabha
# 3                                 Dagger  vigilant_mcclintock
# 4                                 Dagger  vigilant_mcclintock
#
# [5 rows x 35 columns]

# %%
# Remove unneccessary Data
csvTable.drop('ip', inplace = True, axis = 1)
csvTable.drop('finger', inplace = True, axis = 1)
csvTable.drop('name', inplace = True, axis = 1)
csvTable.drop('processedAlignment', inplace = True, axis = 1)
csvTable.drop('good', inplace = True, axis = 1)
csvTable.drop('lawful', inplace = True, axis = 1)
csvTable.drop('processedRace', inplace = True, axis = 1)
csvTable.drop('processedSpells', inplace = True, axis = 1)
csvTable.drop('processedWeapons', inplace = True, axis = 1)

# Output to show that it worked
print('Columns Dropped')
csvTable.head()
# Out:
# Columns Dropped
#                                hash            race              background  \
# 0  fe3ed6570067d2cd808bcee0a4396824      Hill Dwarf  Guild Member - Justice
# 1  aa656cef94740b1da714d82782d8a8c4      Hill Dwarf  Guild Member - Justice
# 2  04b9abba9ce759ef13319c520bf0eb69           Human                   Noble
# 3  ba92372c716a832e03e866447cb2d102  Fallen Aasimar               Outlander
# 4  2f4a637dd42b9aa945abf870fe34edcf  Fallen Aasimar               Outlander
#
#                    date                 class        justClass  \
# 0  2022-08-23T20:02:11Z  Sorcerer 13|Cleric 1  Sorcerer|Cleric
# 1  2022-08-23T19:43:25Z  Sorcerer 13|Cleric 1  Sorcerer|Cleric
# 2  2022-08-22T14:57:09Z            Fighter 13          Fighter
# 3  2022-08-22T12:12:53Z    Sorcerer 3|Druid 2   Sorcerer|Druid
# 4  2022-08-22T12:07:21Z    Sorcerer 3|Druid 2   Sorcerer|Druid
#
#                           subclass  level  \
# 0      Clockwork Soul|Order Domain     14
# 1      Clockwork Soul|Order Domain     14
# 2                  Eldritch Knight     13
# 3  Shadow Magic|Circle of Wildfire      5
# 4  Shadow Magic|Circle of Wildfire      5
#
#                                     feats   HP  ...  Cha       alignment  \
# 0  Fey Touched|War Caster|Metamagic Adept  146  ...   20             NaN
# 1                                     NaN  133  ...   20             NaN
# 2                      Heavy Armor Master  140  ...   10              CG
# 3                                     NaN   34  ...   16  Caltico Neutro
# 4                                     NaN   34  ...   16  Caltico Neutro
#
#                                   skills  \
# 0           Arcana|Religion|Intimidation
# 1           Arcana|Religion|Intimidation
# 2  History|Insight|Perception|Persuasion
# 3      Athletics|Arcana|Insight|Survival
# 4      Athletics|Arcana|Insight|Survival
#
#                                              weapons  \
# 0                             Crossbow, light|Dagger
# 1                             Crossbow, light|Dagger
# 2  Longsword +1|Dagger|Crossbow, light|Mace Of Di...
# 3                                             Dagger
# 4                                             Dagger
#
#                                               spells  castingStat  \
# 0  Alarm*1|Protection from Evil and Good*1|Comman...          Cha
# 1  Alarm*1|Protection from Evil and Good*1|Comman...          Cha
# 2  Prestidigitation*0|Mage Hand*0|Blade Ward*0|Li...          Int
# 3           Burning Hands*1|Cure Wounds*1|Darkness*2          Cha
# 4           Burning Hands*1|Cure Wounds*1|Darkness*2          Cha
#
#                                              choices        country  \
# 0  metamagic/Twinned Spell*Subtle Spell*Quickened...         Canada
# 1  metamagic/Twinned Spell*Subtle Spell*Quickened...         Canada
# 2                             fighting style/Defense  United States
# 3           metamagic/Transmuted Spell*Seeking Spell         Brazil
# 4           metamagic/Transmuted Spell*Seeking Spell         Brazil
#
#   countryCode                alias
# 0          CA      thirsty_davinci
# 1          CA      thirsty_davinci
# 2          US          cool_bhabha
# 3          BR  vigilant_mcclintock
# 4          BR  vigilant_mcclintock
#
# [5 rows x 26 columns]

# %%
# removing duplicates from the dataset
csvTable.drop_duplicates(subset=['alias'], inplace = True)
print('Removed Duplicates')
# Out:
# Removed Duplicates

# %%
# sorting characters based on current level
csvTable.sort_values('level', axis = 0, ascending = True, inplace = True, na_position='first')
print('Csv File ordered by level!')
csvTable.head()
# Out:
# Csv File ordered by level!
#                                   hash      race           background  \
# 5102  56c92961c98aac49411817a565a63b02  Tiefling  Urban Bounty Hunter
# 1846  39120628a1dd2c6beb5674bd639669c1     Human              Soldier
# 5963  a26d8cc84508800f4a065e5ff817b7d8   Sea Elf                 Sage
# 5903  0e6a409c7ea74fd9c5c78cd2c6c9ad40  Wood Elf               Hermit
# 1882  3819682e2080b9f3ae1c6aea22b636b5     Human              Acolyte
#
#                       date       class justClass            subclass  level  \
# 5102  2020-01-09T19:46:02Z   Warlock 1   Warlock           The Fiend      1
# 1846  2021-07-17T15:14:44Z   Fighter 1   Fighter                 NaN      1
# 5963  2019-10-07T19:50:00Z  Sorcerer 1  Sorcerer  Draconic Bloodline      1
# 5903  2019-10-13T04:11:42Z     Druid 1     Druid                 NaN      1
# 1882  2021-07-10T12:01:37Z   Warlock 1   Warlock        The Hexblade      1
#
#                feats  HP  ...  Cha     alignment  \
# 5102             NaN  10  ...   17  Chaotic Good
# 1846  Polearm Master  13  ...   10           NaN
# 5963             NaN   7  ...   15           NaN
# 5903             NaN   9  ...   11           NaN
# 1882  Polearm Master   5  ...   18           NaN
#
#                                                  skills  \
# 5102          Stealth|Deception|Intimidation|Persuasion
# 1846       Athletics|Acrobatics|Perception|Intimidation
# 5963       Arcana|History|Insight|Perception|Persuasion
# 5903  Religion|Animal Handling|Medicine|Perception|S...
# 1882  History|Investigation|Religion|Insight|Perception
#
#                      weapons  spells  castingStat  \
# 5102                  Dagger     NaN          Cha
# 1846    Glaive|Javelin|Spear     NaN          Int
# 5963  Crossbow, light|Dagger     NaN          Cha
# 5903                Scimitar     NaN          Wis
# 1882           Dagger|Dagger     NaN          Cha
#
#                                    choices        country countryCode  \
# 5102         tiefling variants menu/Winged  United States          US
# 1846  fighting style/Great Weapon Fighting  United States          US
# 5963                                   NaN            NaN         NaN
# 5903                                   NaN  United States          US
# 1882                                   NaN         Norway          NO
#
#                    alias
# 5102       youthful_jang
# 1846    cranky_chaplygin
# 5963  compassionate_ride
# 5903      hungry_shirley
# 1882      loving_leavitt
#
# [5 rows x 26 columns]

# %%
# extracting array into variable based on main class
artificer = csvTable[csvTable['justClass'] == 'Artificer']
barbarian = csvTable[csvTable['justClass'] == 'Barbarian']
bard = csvTable[csvTable['justClass'] == 'Bard']
cleric = csvTable[csvTable['justClass'] == 'Cleric']
druid = csvTable[csvTable['justClass'] == 'Druid']
fighter = csvTable[csvTable['justClass'] == 'Fighter']
monk = csvTable[csvTable['justClass'] == 'Monk']
paladin = csvTable[csvTable['justClass'] == 'Paladin']
ranger = csvTable[csvTable['justClass'] == 'Ranger']
rogue = csvTable[csvTable['justClass'] == 'Rogue']
sorcerer = csvTable[csvTable['justClass'] == 'Sorcerer']
warlock = csvTable[csvTable['justClass'] == 'Warlock']
wizard = csvTable[csvTable['justClass'] == 'Wizard']
multiclass = csvTable[csvTable['justClass'].str.contains('\|', na = False)]


# exporting data to seperate csv files
artificer.to_csv('Artificers.csv', index = False)
barbarian.to_csv('Barbarians.csv', index = False)
bard.to_csv('Bards.csv', index = False)
cleric.to_csv('Clerics.csv', index = False)
druid.to_csv('Druids.csv', index = False)
fighter.to_csv('Fighters.csv', index = False)
monk.to_csv('Monks.csv', index = False)
paladin.to_csv('Paladins.csv', index = False)
ranger.to_csv('Rangers.csv', index = False)
rogue.to_csv('Rogues.csv', index = False)
sorcerer.to_csv('Sorcerers.csv', index = False)
warlock.to_csv('Warlocks.csv', index = False)
wizard.to_csv('Wizards.csv', index = False)
multiclass.to_csv('Multiclass.csv', index = False)

print('Classes sorted into csv Files!')
# Out:
# Classes sorted into csv Files!
